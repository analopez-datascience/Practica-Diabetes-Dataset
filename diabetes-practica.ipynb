# %%
import pandas as pd
from sklearn.datasets import load_diabetes
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np

dataSet = load_diabetes()
data = dataSet.data
dataNames = dataSet.feature_names

# %%
df= pd.DataFrame(data)
df
# Out:
#             0         1         2         3         4         5         6  \
# 0    0.038076  0.050680  0.061696  0.021872 -0.044223 -0.034821 -0.043401
# 1   -0.001882 -0.044642 -0.051474 -0.026328 -0.008449 -0.019163  0.074412
# 2    0.085299  0.050680  0.044451 -0.005671 -0.045599 -0.034194 -0.032356
# 3   -0.089063 -0.044642 -0.011595 -0.036656  0.012191  0.024991 -0.036038
# 4    0.005383 -0.044642 -0.036385  0.021872  0.003935  0.015596  0.008142
# ..        ...       ...       ...       ...       ...       ...       ...
# 437  0.041708  0.050680  0.019662  0.059744 -0.005697 -0.002566 -0.028674
# 438 -0.005515  0.050680 -0.015906 -0.067642  0.049341  0.079165 -0.028674
# 439  0.041708  0.050680 -0.015906  0.017282 -0.037344 -0.013840 -0.024993
# 440 -0.045472 -0.044642  0.039062  0.001215  0.016318  0.015283 -0.028674
# 441 -0.045472 -0.044642 -0.073030 -0.081414  0.083740  0.027809  0.173816
#
#             7         8         9
# 0   -0.002592  0.019908 -0.017646
# ...

# %%
df.columns = [dataNames]

# %%
df.head()
# Out:
#         age       sex       bmi        bp        s1        s2        s3  \
# 0  0.038076  0.050680  0.061696  0.021872 -0.044223 -0.034821 -0.043401
# 1 -0.001882 -0.044642 -0.051474 -0.026328 -0.008449 -0.019163  0.074412
# 2  0.085299  0.050680  0.044451 -0.005671 -0.045599 -0.034194 -0.032356
# 3 -0.089063 -0.044642 -0.011595 -0.036656  0.012191  0.024991 -0.036038
# 4  0.005383 -0.044642 -0.036385  0.021872  0.003935  0.015596  0.008142
#
#          s4        s5        s6
# 0 -0.002592  0.019908 -0.017646
# 1 -0.039493 -0.068330 -0.092204
# 2 -0.002592  0.002864 -0.025930
# 3  0.034309  0.022692 -0.009362
# 4 -0.002592 -0.031991 -0.046641

# %%
df.tail()
# Out:
#           age       sex       bmi        bp        s1        s2        s3  \
# 437  0.041708  0.050680  0.019662  0.059744 -0.005697 -0.002566 -0.028674
# 438 -0.005515  0.050680 -0.015906 -0.067642  0.049341  0.079165 -0.028674
# 439  0.041708  0.050680 -0.015906  0.017282 -0.037344 -0.013840 -0.024993
# 440 -0.045472 -0.044642  0.039062  0.001215  0.016318  0.015283 -0.028674
# 441 -0.045472 -0.044642 -0.073030 -0.081414  0.083740  0.027809  0.173816
#
#            s4        s5        s6
# 437 -0.002592  0.031193  0.007207
# 438  0.034309 -0.018118  0.044485
# 439 -0.011080 -0.046879  0.015491
# 440  0.026560  0.044528 -0.025930
# 441 -0.039493 -0.004220  0.003064

# %%
df.size
# Out:
# 4420

# %%
df.shape
# Out:
# (442, 10)

# %%
df.info
# Out:
# <bound method DataFrame.info of           age       sex       bmi        bp        s1        s2        s3  \
# 0    0.038076  0.050680  0.061696  0.021872 -0.044223 -0.034821 -0.043401
# 1   -0.001882 -0.044642 -0.051474 -0.026328 -0.008449 -0.019163  0.074412
# 2    0.085299  0.050680  0.044451 -0.005671 -0.045599 -0.034194 -0.032356
# 3   -0.089063 -0.044642 -0.011595 -0.036656  0.012191  0.024991 -0.036038
# 4    0.005383 -0.044642 -0.036385  0.021872  0.003935  0.015596  0.008142
# ..        ...       ...       ...       ...       ...       ...       ...
# 437  0.041708  0.050680  0.019662  0.059744 -0.005697 -0.002566 -0.028674
# 438 -0.005515  0.050680 -0.015906 -0.067642  0.049341  0.079165 -0.028674
# 439  0.041708  0.050680 -0.015906  0.017282 -0.037344 -0.013840 -0.024993
# 440 -0.045472 -0.044642  0.039062  0.001215  0.016318  0.015283 -0.028674
# 441 -0.045472 -0.044642 -0.073030 -0.081414  0.083740  0.027809  0.173816
#
#            s4        s5        s6
# ...

# %%
df.dtypes
# Out:
# age    float64
# sex    float64
# bmi    float64
# bp     float64
# s1     float64
# s2     float64
# s3     float64
# s4     float64
# s5     float64
# s6     float64
# dtype: object

# %%
df.ndim
# Out:
# 2

# %%
df.loc[df.duplicated()]
# Out:
# Empty DataFrame
# Columns: [(age,), (sex,), (bmi,), (bp,), (s1,), (s2,), (s3,), (s4,), (s5,), (s6,)]
# Index: []

# %%
df.isna().sum()
# Out:
# age    0
# sex    0
# bmi    0
# bp     0
# s1     0
# s2     0
# s3     0
# s4     0
# s5     0
# s6     0
# dtype: int64

# %%
df.isnull().sum()
# Out:
# age    0
# sex    0
# bmi    0
# bp     0
# s1     0
# s2     0
# s3     0
# s4     0
# s5     0
# s6     0
# dtype: int64

# %%
df.corr().T
# Out:
#           age       sex       bmi        bp        s1        s2        s3  \
# age  1.000000  0.173737  0.185085  0.335427  0.260061  0.219243 -0.075181
# sex  0.173737  1.000000  0.088161  0.241013  0.035277  0.142637 -0.379090
# bmi  0.185085  0.088161  1.000000  0.395415  0.249777  0.261170 -0.366811
# bp   0.335427  0.241013  0.395415  1.000000  0.242470  0.185558 -0.178761
# s1   0.260061  0.035277  0.249777  0.242470  1.000000  0.896663  0.051519
# s2   0.219243  0.142637  0.261170  0.185558  0.896663  1.000000 -0.196455
# s3  -0.075181 -0.379090 -0.366811 -0.178761  0.051519 -0.196455  1.000000
# s4   0.203841  0.332115  0.413807  0.257653  0.542207  0.659817 -0.738493
# s5   0.270777  0.149918  0.446159  0.393478  0.515501  0.318353 -0.398577
# s6   0.301731  0.208133  0.388680  0.390429  0.325717  0.290600 -0.273697
#
#            s4        s5        s6
# age  0.203841  0.270777  0.301731
# sex  0.332115  0.149918  0.208133
# bmi  0.413807  0.446159  0.388680
# ...

# %%
plt.figure(figsize=(10, 10))
matriz_corr = df.corr()
sns.heatmap(matriz_corr, annot=True)
plt.show()

# %%
df.describe().T
# Out:
#      count          mean       std       min       25%       50%       75%  \
# age  442.0 -3.634285e-16  0.047619 -0.107226 -0.037299  0.005383  0.038076
# sex  442.0  1.308343e-16  0.047619 -0.044642 -0.044642 -0.044642  0.050680
# bmi  442.0 -8.045349e-16  0.047619 -0.090275 -0.034229 -0.007284  0.031248
# bp   442.0  1.281655e-16  0.047619 -0.112400 -0.036656 -0.005671  0.035644
# s1   442.0 -8.835316e-17  0.047619 -0.126781 -0.034248 -0.004321  0.028358
# s2   442.0  1.327024e-16  0.047619 -0.115613 -0.030358 -0.003819  0.029844
# s3   442.0 -4.574646e-16  0.047619 -0.102307 -0.035117 -0.006584  0.029312
# s4   442.0  3.777301e-16  0.047619 -0.076395 -0.039493 -0.002592  0.034309
# s5   442.0 -3.830854e-16  0.047619 -0.126097 -0.033249 -0.001948  0.032433
# s6   442.0 -3.412882e-16  0.047619 -0.137767 -0.033179 -0.001078  0.027917
#
#           max
# age  0.110727
# sex  0.050680
# bmi  0.170555
# bp   0.132044
# s1   0.153914
# s2   0.198788
# s3   0.181179
# s4   0.185234
# ...

# %%
#df.describe(include = ['O']).T

# %%
df.head()
# Out:
#         age       sex       bmi        bp        s1        s2        s3  \
# 0  0.038076  0.050680  0.061696  0.021872 -0.044223 -0.034821 -0.043401
# 1 -0.001882 -0.044642 -0.051474 -0.026328 -0.008449 -0.019163  0.074412
# 2  0.085299  0.050680  0.044451 -0.005671 -0.045599 -0.034194 -0.032356
# 3 -0.089063 -0.044642 -0.011595 -0.036656  0.012191  0.024991 -0.036038
# 4  0.005383 -0.044642 -0.036385  0.021872  0.003935  0.015596  0.008142
#
#          s4        s5        s6
# 0 -0.002592  0.019908 -0.017646
# 1 -0.039493 -0.068330 -0.092204
# 2 -0.002592  0.002864 -0.025930
# 3  0.034309  0.022692 -0.009362
# 4 -0.002592 -0.031991 -0.046641

# %%
df1 = df.replace(0.050680, 0)
df2 = df1.replace(-0.044642, 1)
#df['sex'] = df.sex.replace({'0.050680':0, '-0.044642':1})
#df = df.replace({'0.050680':0})
df.head()
# Out:
#         age       sex       bmi        bp        s1        s2        s3  \
# 0  0.038076  0.050680  0.061696  0.021872 -0.044223 -0.034821 -0.043401
# 1 -0.001882 -0.044642 -0.051474 -0.026328 -0.008449 -0.019163  0.074412
# 2  0.085299  0.050680  0.044451 -0.005671 -0.045599 -0.034194 -0.032356
# 3 -0.089063 -0.044642 -0.011595 -0.036656  0.012191  0.024991 -0.036038
# 4  0.005383 -0.044642 -0.036385  0.021872  0.003935  0.015596  0.008142
#
#          s4        s5        s6
# 0 -0.002592  0.019908 -0.017646
# 1 -0.039493 -0.068330 -0.092204
# 2 -0.002592  0.002864 -0.025930
# 3  0.034309  0.022692 -0.009362
# 4 -0.002592 -0.031991 -0.046641

# %%
#df.loc[df['sex'] == '0.050680', 'sex'] = '0'
#df.loc[df['sex'] == '-0.044642', 'sex'] = '1'

# %%
#df['nueva_col']=np.where(df['sex']=='0.050680':0)
                #np.where(df['sex']=='0.044642':1)

# %%
def covertir_binarias (x):
    if x < 0: 
        mensaje = 1
    else: 
        mensaje = 2
    return mensaje

def asdf(x):
    if 

df['sex'] = df['sex'].apply(covertir_binarias)
df.head()
# Out:
#   Input In [22]
#     if
#        ^
# SyntaxError: invalid syntax

# %%
df['sex'].value_counts()
# Out:
# (sex,)
# -0.044642    235
#  0.050680    207
# dtype: int64

# %%
df.head()
# Out:
#         age       sex       bmi        bp        s1        s2        s3  \
# 0  0.038076  0.050680  0.061696  0.021872 -0.044223 -0.034821 -0.043401
# 1 -0.001882 -0.044642 -0.051474 -0.026328 -0.008449 -0.019163  0.074412
# 2  0.085299  0.050680  0.044451 -0.005671 -0.045599 -0.034194 -0.032356
# 3 -0.089063 -0.044642 -0.011595 -0.036656  0.012191  0.024991 -0.036038
# 4  0.005383 -0.044642 -0.036385  0.021872  0.003935  0.015596  0.008142
#
#          s4        s5        s6
# 0 -0.002592  0.019908 -0.017646
# 1 -0.039493 -0.068330 -0.092204
# 2 -0.002592  0.002864 -0.025930
# 3  0.034309  0.022692 -0.009362
# 4 -0.002592 -0.031991 -0.046641

# %%
df['sex'] = df['sex'].astype('category')
df['age'] = df['age'].astype('category')

# %%
import seaborn as sns
sns.set_theme(style="ticks", palette="pastel")

# Draw a nested boxplot to show bills by day and time
sns.boxplot(x="sex", y="age",
            hue="bp", palette=["m", "g"],
            data=df)
sns.despine(offset=10, trim=True)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Input In [30], in <cell line: 5>()
#       2 sns.set_theme(style="ticks", palette="pastel")
#       4 # Draw a nested boxplot to show bills by day and time
# ----> 5 sns.boxplot(x="sex", y="age",
#       6             hue="bp", palette=["m", "g"],
#       7             data=df)
#       8 sns.despine(offset=10, trim=True)
#
# File /opt/anaconda3/lib/python3.9/site-packages/seaborn/_decorators.py:46, in _deprecate_positional_args.<locals>.inner_f(*args, **kwargs)
#      36     warnings.warn(
#      37         "Pass the following variable{} as {}keyword arg{}: {}. "
#      38         "From version 0.12, the only valid positional argument "
#    (...)
#      43         FutureWarning
#      44     )
#      45 kwargs.update({k: arg for k, arg in zip(sig.parameters, args)})
# ---> 46 return f(**kwargs)
#
# ...
